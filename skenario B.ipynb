# %%
from Tools import myplot, mytimer
import time
import pandas as pd
import numpy as np
import os
import cv2
import json
from IPython.display import clear_output
from scipy.ndimage import map_coordinates, uniform_filter, sobel
from skimage.util import view_as_windows
from sklearn.model_selection import train_test_split
from sklearn.base import clone
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import pickle
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
import tensorflow as tf
# from tensorflow.keras.applications import EfficientNetB0, ResNet50, MobileNetV3Small
# from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input, Conv2D, GlobalMaxPool2D, Concatenate, BatchNormalization
# from tensorflow.keras.models import Model
# from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import tracemalloc
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import matplotlib

# %%
print("TF =", tf.__version__)
print("Keras =", tf.keras.__version__)
# Out:
# TF = 2.21.0
# Keras = 3.13.2

# %% [markdown]
# #### Inisialisasi

# %%
with open('settings.json', 'r') as f:
    dict_settings = json.load(f)

print(json.dumps(dict_settings, indent=4))
# Out:
# {
#     "PATH_FOLDER": {
#         "dataset": "Dataset",
#         "dataset_pre": "Dataset_Preprocessing",
#         "dataset_extract_a": "Dataset_Extract_A",
#         "dataset_extract_b": "Dataset_Extract_B",
#         "dataset_extract_d": "Dataset_Extract_D",
#         "dataset_plot": "Plot_Dataset",
#         "dataset_extract_a_plot": "Plot_Dataset_Extract_A",
#         "dataset_extract_b_plot": "Plot_Dataset_Extract_B",
#         "dataset_extract_d_plot": "Plot_Dataset_Extract_D",
#         "path_model_plot": "Plot_Evaluasi",
#         "path_plot": "Plot",
#         "path_excel": "Excel",
#         "path_model_a": "Model_A",
#         "path_model_b": "Model_B",
#         "path_model_c": "Model_C",
#         "path_model_d": "Model_D"
#     },
#     "PATH_FILE": {
#         "dataset": "Excel\\dataset.xlsx",
#         "dataset_extract_a": "Excel\\dataset_extract_A.xlsx",
#         "dataset_extract_b": "Excel\\dataset_extract_B.xlsx",
#         "dataset_selected_c": "Excel\\dataset_selected_C.xlsx",
#         "dataset_extract_d": "Excel\\dataset_extract_D.xlsx",
#         "dataset_selected_d": "Excel\\dataset_selected_D.xlsx"
#     },
#     "IMAGE_SIZE": [
#         224,
#         224
#     ],
#     "EXTENSIONS": [
#         ".jpg",
#         ".png",
#         ".jpeg"
#     ],
#     "DEFAULT_EXTENSION": ".png",
#     "DEFAULT_EXTENSION_PLOT": ".jpg"
# }

# %%
PATH_FOLDER = dict_settings['PATH_FOLDER']
PATH_FILE = dict_settings['PATH_FILE']
IMAGE_SIZE = dict_settings['IMAGE_SIZE']
DEFAULT_EXTENSION = dict_settings['DEFAULT_EXTENSION']
DEFAULT_EXTENSION_PLOT = dict_settings['DEFAULT_EXTENSION_PLOT']

# %% [markdown]
# # 1. DATASET
# ___

# %%
df = pd.read_excel(PATH_FILE['dataset'])
df
# Out:
#                    LOKASI_GAMBAR SUMBER_DATASET  LABEL
# 0   dataset_1\0\ef5155990874.png      dataset_1      0
# 1   dataset_1\0\0a85a1e8f9e9.png      dataset_1      0
# 2   dataset_1\0\6a2642131e4a.png      dataset_1      0
# 3   dataset_1\0\8a8a251770cd.png      dataset_1      0
# 4   dataset_1\0\ac1667fac512.png      dataset_1      0
# 5   dataset_1\0\78937523f7a8.png      dataset_1      0
# 6   dataset_1\0\42af7282349b.png      dataset_1      0
# 7   dataset_1\0\ff4832d55461.png      dataset_1      0
# 8   dataset_1\0\41345cec5957.png      dataset_1      0
# 9   dataset_1\0\5077cdb88aed.png      dataset_1      0
# 10  dataset_1\0\369229040a34.png      dataset_1      0
# 11  dataset_1\0\e4c799738a19.png      dataset_1      0
# 12  dataset_1\0\4eabad7948cf.png      dataset_1      0
# 13  dataset_1\0\1d29cb2f4296.png      dataset_1      0
# 14  dataset_1\0\4c60f6fcea75.png      dataset_1      0
# 15  dataset_1\0\7f39c36469b5.png      dataset_1      0
# 16  dataset_1\0\afc744fad65e.png      dataset_1      0
# 17  dataset_1\0\fa7fa797c650.png      dataset_1      0
# 18  dataset_1\0\e59c5f345bb0.png      dataset_1      0
# 19  dataset_1\0\dee1031a76ae.png      dataset_1      0
# 20  dataset_1\1\a19ecd0a706e.png      dataset_1      1
# 21  dataset_1\1\abdb365cacbc.png      dataset_1      1
# 22  dataset_1\1\d6e26fe51dce.png      dataset_1      1
# 23  dataset_1\1\4029d70e9d8a.png      dataset_1      1
# 24  dataset_1\1\ca6842bfcbc9.png      dataset_1      1
# 25  dataset_1\1\5a091e8cd95c.png      dataset_1      1
# 26  dataset_1\1\bb9a3d835a94.png      dataset_1      1
# 27  dataset_1\1\3de8ad4151e1.png      dataset_1      1
# 28  dataset_1\1\278aa860dffd.png      dataset_1      1
# 29  dataset_1\1\76e589911303.png      dataset_1      1
# 30  dataset_1\1\29b52f64d2db.png      dataset_1      1
# 31  dataset_1\1\03e25101e8e8.png      dataset_1      1
# 32  dataset_1\1\66cd9c28e636.png      dataset_1      1
# 33  dataset_1\1\80d24897669f.png      dataset_1      1
# 34  dataset_1\1\bebb3f167654.png      dataset_1      1
# 35  dataset_1\1\49c5e7f6b8d2.png      dataset_1      1
# 36  dataset_1\1\8273fdb4405e.png      dataset_1      1
# 37  dataset_1\1\4d7d6928534a.png      dataset_1      1
# 38  dataset_1\1\c4a8f2fcf6e8.png      dataset_1      1
# 39  dataset_1\1\7b20210d9120.png      dataset_1      1

# %% [markdown]
# # 2. EKSTRAKSI FITUR
# ___

# %%
# =====================================================================
# 1. Bilinear Interpolation Sampling
# =====================================================================
def bilinear_interpolate_full(image, x, y):
    return map_coordinates(image, [[y], [x]], order=1, mode='reflect')[0]

# =====================================================================
# 2. Noise-Aware Thresholding
# =====================================================================
def compute_noise_threshold_map(img, size=3, k=0.5):
    mu = uniform_filter(img, size=size, mode='reflect')
    mu2 = uniform_filter(img * img, size=size, mode='reflect')
    sigma = np.sqrt(np.maximum(mu2 - mu * mu, 0))
    return mu + k * sigma

# =====================================================================
# 3. Graph Connectivity Weighting
# =====================================================================
def get_graph_neighbors(P, R):
    angles = np.linspace(0, 2*np.pi, P, endpoint=False)
    coords = [(R*np.cos(a), R*np.sin(a)) for a in angles]
    return coords

def adaptive_normalize(img, eps=1e-8):
    img = img.astype(np.float32)
    vmin, vmax = img.min(), img.max()

    # Normalisasi hanya jika belum pada rentang stabil
    if vmax > 1.0 + eps:
        img = (img - vmin) / (vmax - vmin + eps)


    return img

# Jarak
def distance_weight(dx, dy):
    d = np.sqrt(dx**2 + dy**2)
    return 1.0 / (d + 1e-8)

# Gradien Lokal
def gradient_weight(img, size=3, eps=1e-8):
    img = adaptive_normalize(img)

    gx = sobel(img, axis=1, mode='reflect')
    gy = sobel(img, axis=0, mode='reflect')

    grad_mag = np.sqrt(gx**2 + gy**2)

    # Normalisasi berbasis statistik lokal
    local_mean = uniform_filter(grad_mag, size=size)
    grad_w = grad_mag / (local_mean + eps)

    return grad_w

# Konsistensi pola MA
def consistency_weight(img, size=3, eps=1e-8):
    img = adaptive_normalize(img)

    # --------------------------------------------------
    # 2) MA consistency
    # --------------------------------------------------
    local_mean = uniform_filter(img, size=size)
    diff = np.abs(img - local_mean)

    # Normalisasi berbasis statistik lokal
    local_diff_mean = uniform_filter(diff, size=size)

    konstitusi = 1.0 / (1.0 + diff / (local_diff_mean + eps))

    return konstitusi

# =====================================================================
# 5. Graph-Based LBP Calculation
    # - Bilinear interpolation (Modifikasi 1)
    # - Noise-aware threshold (Modifikasi 2)
    # - Graph connectivity weighting (Modifikasi 3)
# =====================================================================
def graph_based_lbp(image, P=8, R=1, k_thresh=0.5, ent_win=3, n_bins=8):
    img = image.astype(np.float32)
    # NORMALISASI GLOBAL
    # img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX)
    H, W = img.shape

    center = img
    # Meshgrid piksel
    yy, xx = np.meshgrid(np.arange(H), np.arange(W), indexing='ij')

    # Entropy Map
    entropy_map = compute_entropy_map(img, win=ent_win, n_bins=n_bins)
    # Konstitusi pola MA
    konstitusi = consistency_weight(entropy_map)

    # Neighbor sampling
    neighbors = get_graph_neighbors(P, R)

    bits = []
    for i, (dx, dy) in enumerate(neighbors):
        # Modifikasi 1: Bilinear Interpolation
        intensitas = bilinear_interpolate_full(img, xx + dx, yy + dy)
        
        # Modifikasi 2: Noise Aware Thresholding
        noise_aware = compute_noise_threshold_map(intensitas, k=k_thresh)        
        intensitas_noise = np.where(intensitas >= noise_aware, noise_aware, intensitas)

        # Modifikasi 3: Graph Connectivity Weighting
        # Gradien Lokal
        grad = gradient_weight(intensitas)
        # Jarak
        dist = distance_weight(dx, dy)
        
        # Hitung Bobot
        W = dist * grad * konstitusi
        W = W / (np.mean(W) + 1e-8)
        # Tambahkan bobot pada tetangga
        bit = ((intensitas_noise - center) * W >= 0).astype(np.uint8)

        bits.append(bit)

    # Encode LBP
    bits = np.stack(bits, axis=-1)

    return bits, entropy_map
# ==============================================================
# 6. Entropy Map
# ==============================================================
def compute_entropy_map(img, win=3, n_bins=8, show_mask=False):
    # Buat patch sliding window: shape (H-win+1, W-win+1, win, win)
    patches = view_as_windows(img, (win, win))
    ph, pw = patches.shape[:2]

    # Flatten 1 patch = win*win piksel
    flat = patches.reshape(-1, win * win)

    # Histogram quantization
    bins = np.linspace(img.min(), img.max() + 1e-6, n_bins + 1)
    inds = np.digitize(flat, bins) - 1

    # Hitung histogram 8 bin
    hist = np.zeros((len(flat), n_bins), dtype=np.float32)
    for b in range(n_bins):
        hist[:, b] = (inds == b).sum(axis=1)

    # Normalisasi: jumlah piksel per window = win*win
    probs = hist / (win * win)

    # Hitung entropy tiap window
    with np.errstate(divide='ignore', invalid='ignore'):
        ent = -np.sum(np.where(probs > 0, probs * np.log(probs), 0), axis=1)

    # Kembalikan ke bentuk spasial
    entropy_map = ent.reshape(ph, pw)
    # Ubah nilai kurang dari 0 menjadi 0
    entropy_map[entropy_map < 1e-8] = 0.0

    # Padding Agar ukuran Kembali
    pad = win // 2
    entropy_map = np.pad(entropy_map, pad_width=pad, mode='reflect')

    # Kandidat MA
    mask = entropy_map > (entropy_map.mean() + 1.5 * entropy_map.std())
    entropy_map = np.where(mask, entropy_map, 0)

    if show_mask:
        return mask, entropy_map

    return entropy_map

# ==============================================================
# 7. Histogram G-LBP (UNIFORM, LBP^u2)
# ==============================================================
def glbp_histogram(bits, P=8, method="uniform"):
    if method == 'uniform':
        # uniform LBP → P + 2 bin
        n_bins = P + 2
        # Hitung transisi circular dan jumlah ones
        transitions = np.sum(bits != np.roll(bits, 1, axis=-1), axis=-1)
        ones_count = np.sum(bits, axis=-1)
        glbp_image = np.where(transitions <= 2, ones_count, P + 1).astype(np.uint8)
    else:
        n_bins = 2**P
        powers_of_two = 2 ** np.arange(P)
        glbp_image = np.tensordot(bits, powers_of_two, axes=([2], [0])).astype(np.uint8)

    # Histogram
    hist, _ = np.histogram(
        glbp_image.ravel(),
        bins=n_bins,
        range=(0, n_bins)
    )

    # Normalisasi
    hist = hist.astype(np.float32)
    hist /= (hist.sum() + 1e-8)

    feature_names = [f"LBP_{i}" for i in range(n_bins)]
    return glbp_image, dict(zip(feature_names, hist))

# =====================================================================
# 7. Pipeline Ekstraksi Fitur GLBP (Untuk Green Channel)
# =====================================================================
def extract_glbp_features(image_input, P=8, R=1, ent_win=3, n_bins=8, method="default"):
    # Muat Gambar
    if isinstance(image_input, str):
        img = cv2.imread(image_input, cv2.IMREAD_COLOR)
        if img is None:
            raise FileNotFoundError(f"File tidak ditemukan: {image_input}")
    else:
        img = image_input
    # Gunakan green channel (sesuai standar citra fundus)
    if img.ndim == 3:
        green_channel = img[:, :, 1]
    else:
        green_channel = img.astype(np.uint8)

    # Extract G-LBP
    bits, entropy_map = graph_based_lbp(image=green_channel, P=P, R=R, ent_win=ent_win, n_bins=n_bins)
    # Histogram
    glbp_image, hist = glbp_histogram(bits=bits, P=P, method=method)
    

    return {
        "glbp_image": glbp_image,
        "glbp_histogram": hist,
        "entropy_map": entropy_map
    }

# %% [markdown]
# ## Visualisasi Hasil Ekstraksi Fitur

# %%
# %matplotlib inline
iloc = 0

for label in df['LABEL'].unique():
    print(f"Label: {label}")
    example_path = df[df['LABEL'] == label].iloc[iloc]['LOKASI_GAMBAR']

    # Baca gambar
    img_pre = cv2.imread(f"{PATH_FOLDER['dataset_pre']}/{example_path}")
    img_pre = cv2.cvtColor(img_pre, cv2.IMREAD_COLOR)

    # Proses Ekstraksi GLBP
    process_extract = extract_glbp_features(image_input=img_pre)
    # Data Hasil Ekstraksi
    glbp_image = process_extract.get('glbp_image', [])
    img_entropy = process_extract.get('entropy_map', [])
    glbp_features = process_extract.get('glbp_histogram', [])  # dict fitur histogram

    # Ambil histogram
    hist_values = list(glbp_features.values())
    hist_labels = list(glbp_features.keys())

    # Tampilkan Plot
    myplot.plot_glbp_example(
        img_pre=img_pre,
        img_entropy=img_entropy,
        glbp_image=glbp_image,
        hist_values=hist_values
    )
# Out:
# Label: 0
# Label: 1

# %% [markdown]
# ## Proses Ekstraksi Fitur

# %%
matplotlib.use('Agg')

# Mulai timer
timer = mytimer.loop_timer()
next(timer)

total_iterasi = len(df)
time_list = []

dict_extract_features = {}
for i, (index, item) in enumerate(df.iterrows()):
    clear_output(wait=True)  # Progress lebih bersih

    # =================================================
    # 1. Path lokasi gambar
    # =================================================
    path_file = item['LOKASI_GAMBAR']
    filename, ext = os.path.splitext(path_file)

    path_img_pre = os.path.join(PATH_FOLDER['dataset_pre'], f"{filename}{DEFAULT_EXTENSION}") # Lokasi Gambar Preprocessing
    path_glbp_img = os.path.join(PATH_FOLDER['dataset_extract_b'], f"{filename}{DEFAULT_EXTENSION}") # Lokasi Gambar Ekstraksi GLBP
    path_entropy_npy = os.path.join(PATH_FOLDER['dataset_extract_b'], f"{filename}_entropy.npy") # Lokasi Entropy GLBP
    path_plot = os.path.join(PATH_FOLDER['dataset_extract_b_plot'], f"{filename}_plot{DEFAULT_EXTENSION_PLOT}") # Lokasi Plot

    # =================================================
    # 2. Ekstraksi GLBP
    # =================================================
    img_pre = cv2.imread(path_img_pre, cv2.IMREAD_COLOR)
    result = extract_glbp_features(image_input=img_pre)

    # Ambil hasil ekstraksi
    glbp_img = result.get("glbp_image")
    glbp_hist = result.get("glbp_histogram")
    glbp_entropy = result.get("entropy_map")
    label = item['LABEL']
    hist_values = list(glbp_hist.values())
    
    # =================================================
    # Simpan Gambar
    # =================================================
    # Hapus gambar sebelumnya
    if os.path.exists(path_glbp_img):
        os.remove(path_glbp_img)
    if os.path.exists(path_entropy_npy):
        os.remove(path_entropy_npy)
        
    # GLBP
    rgb_glbp = cv2.merge([glbp_img, glbp_img, glbp_img])
    cv2.imwrite(path_glbp_img, rgb_glbp)
    # Entropy Map
    np.save(path_entropy_npy, glbp_entropy)

    # =================================================
    # 4. Simpan fitur histogram (untuk DataFrame)
    # =================================================
    dict_extract_features[index] = {
        **glbp_hist,
        "LABEL": label
    }

    # =============================================================================
    # Simpan Plot
    # =============================================================================
    myplot.plot_glbp_example(
        img_pre=img_pre,
        img_entropy=glbp_entropy,
        glbp_image=glbp_img,
        hist_values=hist_values,
        save_as=path_plot,
        show=False
    )

    # =================================================
    # Hitung waktu iterasi
    # =================================================
    dt = timer.send("tick")
    if dt is not None:
        time_list.append(dt)

    print(f"Proses Ekstraksi GLBP... {i + 1}/{total_iterasi}")
    print(f"Waktu iterasi ini: {mytimer.format_time(dt)}")


# =====================================================
# Akhiri timer dan hitung rata-rata waktu
# =====================================================
info = timer.send("done")
info["avg_time"] = sum(time_list) / len(time_list)

# =====================================================
# Tampilkan Ringkasan
# =====================================================
print("\n======================")
print("       RINGKASAN     ")
print("======================")
print(f"Total iterasi            : {total_iterasi}")
print(f"Total waktu              : {mytimer.format_time(info['total_time'])}")
print(f"Rata-rata waktu/iterasi  : {mytimer.format_time(info['avg_time'])}")
# Out:
# Proses Ekstraksi GLBP... 40/40
# Waktu iterasi ini: 2 detik
#
# ======================
#        RINGKASAN
# ======================
# Total iterasi            : 40
# Total waktu              : 1 menit 14 detik
# Rata-rata waktu/iterasi  : 1 detik

# %%
# Mengubah menjadi dataframe
df_features = pd.DataFrame.from_dict(dict_extract_features, orient='index')
# Simpan dataset ekstrasi
df_features.to_excel(PATH_FILE['dataset_extract_b'], index=None)
df_features
# Out:
#        LBP_0     LBP_1     LBP_2     LBP_3     LBP_4     LBP_5     LBP_6  \
# 0   0.126395  0.008450  0.001016  0.001953  0.008789  0.001754  0.001933
# 1   0.132374  0.007992  0.000638  0.001933  0.011818  0.002910  0.002272
# 2   0.113341  0.007235  0.000438  0.000817  0.006776  0.001794  0.001335
# 3   0.126256  0.008550  0.000937  0.002053  0.009327  0.002192  0.001953
# 4   0.126515  0.008610  0.000797  0.002412  0.008610  0.002172  0.002790
# 5   0.081035  0.008669  0.000458  0.002810  0.006019  0.001156  0.003567
# 6   0.128368  0.009287  0.000239  0.000698  0.011380  0.002073  0.001016
# 7   0.087412  0.008929  0.001116  0.003368  0.006258  0.000996  0.003567
# 8   0.072844  0.007414  0.000737  0.003189  0.005461  0.000717  0.003488
# 9   0.120954  0.009626  0.000678  0.001913  0.009287  0.001515  0.001674
# 10  0.123984  0.008849  0.000837  0.001993  0.008151  0.001774  0.001973
# 11  0.123326  0.008610  0.000438  0.001176  0.007992  0.001794  0.001096
# 12  0.081593  0.007952  0.001036  0.004066  0.005999  0.000777  0.003926
# 13  0.142917  0.010324  0.000698  0.001654  0.010922  0.002172  0.001734
# 14  0.103835  0.011101  0.000279  0.001156  0.008610  0.001614  0.001116
# 15  0.127730  0.009048  0.001415  0.003787  0.007852  0.001913  0.002830
# 16  0.123426  0.009447  0.000877  0.002132  0.008650  0.001933  0.002691
# 17  0.125319  0.008909  0.000698  0.002132  0.008749  0.001574  0.002192
# 18  0.128189  0.008211  0.000897  0.002631  0.008669  0.001973  0.002571
# 19  0.098135  0.010025  0.000498  0.001375  0.009028  0.001276  0.001574
# 20  0.106485  0.009786  0.000199  0.000877  0.010065  0.001873  0.001176
# 21  0.118304  0.010124  0.000598  0.002451  0.009666  0.001694  0.002272
# 22  0.114736  0.009507  0.000319  0.001036  0.009945  0.001475  0.001315
# 23  0.112265  0.010065  0.001315  0.004524  0.008650  0.001415  0.004305
# 24  0.129564  0.011440  0.000638  0.001834  0.010842  0.001834  0.001734
# 25  0.131457  0.010543  0.000857  0.002651  0.008929  0.001953  0.003089
# 26  0.121732  0.010902  0.000678  0.001574  0.009746  0.001555  0.001694
# 27  0.132713  0.012337  0.000658  0.001993  0.012117  0.001475  0.001834
# 28  0.135005  0.013273  0.000777  0.001495  0.012875  0.002730  0.001654
# 29  0.124601  0.010662  0.000359  0.000957  0.009247  0.001495  0.001116
# 30  0.093092  0.008769  0.000698  0.003747  0.008530  0.001036  0.003607
# 31  0.139369  0.008390  0.000299  0.001375  0.011619  0.001594  0.001355
# 32  0.126495  0.010523  0.001076  0.002511  0.010025  0.001873  0.002431
# 33  0.115035  0.010862  0.000319  0.000937  0.010563  0.002033  0.001056
# 34  0.125419  0.011360  0.000299  0.001654  0.011141  0.002392  0.001694
# 35  0.126634  0.012038  0.000917  0.002152  0.011021  0.002292  0.001993
# 36  0.125438  0.012576  0.000558  0.001495  0.011141  0.001993  0.001276
# 37  0.112962  0.010463  0.000957  0.002551  0.009407  0.001614  0.002631
# 38  0.113361  0.010702  0.000419  0.002152  0.009507  0.002053  0.002232
# 39  0.106545  0.009965  0.000578  0.001256  0.008291  0.001375  0.002013
#
#        LBP_7     LBP_8     LBP_9  ...   LBP_247   LBP_248   LBP_249   LBP_250  \
# 0   0.005879  0.000937  0.000060  ...  0.000618  0.002790  0.001295  0.000000
# 1   0.006338  0.000379  0.000060  ...  0.000777  0.001953  0.001216  0.000000
# 2   0.003368  0.000538  0.000040  ...  0.000578  0.002252  0.000438  0.000000
# 3   0.005261  0.000658  0.000159  ...  0.000598  0.002910  0.001116  0.000000
# 4   0.007215  0.000817  0.000060  ...  0.000917  0.003169  0.001415  0.000040
# 5   0.007932  0.000897  0.000040  ...  0.000379  0.009706  0.002132  0.000419
# 6   0.002830  0.000458  0.000020  ...  0.000339  0.000737  0.000299  0.000000
# 7   0.008849  0.001315  0.000060  ...  0.000757  0.007733  0.003807  0.000419
# 8   0.008709  0.000917  0.000000  ...  0.000897  0.007593  0.003348  0.000239
# 9   0.005142  0.000678  0.000040  ...  0.000578  0.002651  0.000797  0.000000
# 10  0.004305  0.000678  0.000040  ...  0.000717  0.003348  0.001116  0.000020
# 11  0.003528  0.000698  0.000060  ...  0.000319  0.002172  0.000717  0.000000
# 12  0.008669  0.000937  0.000080  ...  0.000698  0.008371  0.003328  0.000478
# 13  0.006258  0.000598  0.000000  ...  0.000658  0.001555  0.000757  0.000000
# 14  0.003667  0.000419  0.000060  ...  0.000458  0.001495  0.000458  0.000000
# 15  0.006198  0.001295  0.000140  ...  0.001076  0.003567  0.001734  0.000060
# 16  0.005700  0.000837  0.000120  ...  0.000638  0.003268  0.001415  0.000000
# 17  0.004703  0.000498  0.000000  ...  0.000478  0.002312  0.001116  0.000020
# 18  0.007155  0.000937  0.000060  ...  0.000837  0.003328  0.001415  0.000040
# 19  0.003627  0.000518  0.000000  ...  0.000618  0.001216  0.000419  0.000000
# 20  0.003667  0.000259  0.000020  ...  0.000478  0.001355  0.000359  0.000000
# 21  0.005760  0.000797  0.000040  ...  0.000698  0.001734  0.000837  0.000000
# 22  0.004624  0.000279  0.000020  ...  0.000498  0.001256  0.000538  0.000000
# 23  0.009786  0.001236  0.000060  ...  0.001036  0.006956  0.003069  0.000399
# 24  0.003807  0.000957  0.000040  ...  0.000279  0.001176  0.000279  0.000000
# 25  0.005879  0.001116  0.000080  ...  0.000877  0.003288  0.001853  0.000020
# 26  0.002910  0.000837  0.000100  ...  0.000458  0.001036  0.000279  0.000000
# 27  0.007055  0.000717  0.000060  ...  0.000897  0.001415  0.000618  0.000000
# 28  0.004703  0.000558  0.000060  ...  0.000578  0.001176  0.000498  0.000000
# 29  0.003647  0.000359  0.000000  ...  0.000100  0.001076  0.000259  0.000000
# 30  0.010543  0.000996  0.000100  ...  0.000837  0.008311  0.002790  0.000179
# 31  0.003707  0.000817  0.000020  ...  0.000498  0.001475  0.000478  0.000020
# 32  0.005281  0.000957  0.000040  ...  0.000837  0.001674  0.000757  0.000000
# 33  0.003448  0.000199  0.000040  ...  0.000299  0.000737  0.000199  0.000000
# 34  0.004703  0.000538  0.000040  ...  0.000498  0.001295  0.000339  0.000000
# 35  0.005859  0.001016  0.000040  ...  0.001236  0.001973  0.000817  0.000000
# 36  0.004245  0.000458  0.000020  ...  0.000598  0.001814  0.000538  0.000000
# 37  0.005301  0.000797  0.000060  ...  0.000817  0.002332  0.001176  0.000000
# 38  0.005919  0.000678  0.000060  ...  0.000877  0.002332  0.001016  0.000020
# 39  0.004684  0.000698  0.000000  ...  0.000478  0.001236  0.000558  0.000000
#
#      LBP_251   LBP_252   LBP_253   LBP_254   LBP_255  LABEL
# 0   0.000140  0.000937  0.000558  0.000060  0.699757      0
# 1   0.000279  0.001455  0.001176  0.000100  0.669762      0
# 2   0.000100  0.000857  0.000498  0.000339  0.751236      0
# 3   0.000199  0.000996  0.000797  0.000060  0.695053      0
# 4   0.000239  0.001016  0.000957  0.000100  0.667132      0
# 5   0.003288  0.002611  0.000498  0.002910  0.602499      0
# 6   0.000020  0.000717  0.000319  0.000060  0.761221      0
# 7   0.004305  0.003169  0.000717  0.004106  0.568319      0
# 8   0.003528  0.003966  0.001116  0.003528  0.600347      0
# 9   0.000080  0.000717  0.000797  0.000259  0.713748      0
# 10  0.000199  0.000996  0.000678  0.000100  0.705995      0
# 11  0.000060  0.000777  0.000359  0.000040  0.742666      0
# 12  0.004086  0.003767  0.000917  0.004026  0.556302      0
# 13  0.000100  0.000977  0.000717  0.000100  0.690470      0
# 14  0.000040  0.000996  0.000538  0.000518  0.758171      0
# 15  0.000578  0.002113  0.000996  0.000638  0.635523      0
# 16  0.000159  0.001256  0.000737  0.000159  0.679448      0
# 17  0.000120  0.001076  0.000737  0.000159  0.715262      0
# 18  0.000219  0.001435  0.000678  0.000179  0.662628      0
# 19  0.000159  0.000917  0.000678  0.000777  0.756417      0
# 20  0.000040  0.000757  0.000498  0.000339  0.743184      1
# 21  0.000080  0.001216  0.000737  0.000419  0.688257      1
# 22  0.000060  0.000678  0.000159  0.000359  0.741789      1
# 23  0.002770  0.003488  0.000797  0.002471  0.519870      1
# 24  0.000120  0.000777  0.000359  0.000339  0.712811      1
# 25  0.000339  0.002073  0.000957  0.000598  0.631358      1
# 26  0.000040  0.000837  0.000259  0.000319  0.741709      1
# 27  0.000199  0.001056  0.001076  0.000438  0.678492      1
# 28  0.000060  0.000917  0.000578  0.000339  0.688536      1
# 29  0.000000  0.000558  0.000299  0.000259  0.746911      1
# 30  0.003767  0.003368  0.000518  0.002989  0.536711      1
# 31  0.000080  0.000698  0.000379  0.000498  0.716219      1
# 32  0.000319  0.001196  0.000578  0.000538  0.678352      1
# 33  0.000020  0.000359  0.000438  0.000279  0.757753      1
# 34  0.000080  0.000857  0.000438  0.000379  0.714106      1
# 35  0.000159  0.001036  0.000817  0.000498  0.666036      1
# 36  0.000179  0.001056  0.000518  0.000259  0.713927      1
# 37  0.000319  0.001734  0.000578  0.000598  0.680206      1
# 38  0.000419  0.001295  0.000698  0.000359  0.682219      1
# 39  0.000020  0.000897  0.000399  0.000399  0.739298      1
#
# [40 rows x 257 columns]

# %% [markdown]
# # 3. PEMBAGIAN DATASET
# ___

# %% [markdown]
# #### Memisahkan Dataframe Features berdasarkan Sumber Dataset

# %%
df_features = pd.read_excel(PATH_FILE['dataset_extract_b'])

# %%
dict_split = {}
for sumber in np.unique(df['SUMBER_DATASET']):
    # Mengambil index dengan sumber berbeda
    unique_index = list(df[df['SUMBER_DATASET'] == sumber].index)
    # Memasukkan dataset df_features ke dalam dictionary
    find_features = df_features.iloc[unique_index]

    # Lakukan Pembagian Dataset Training dan Testing
    X = find_features.drop('LABEL', axis=1)
    y = find_features['LABEL']
    X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                        train_size=0.8, 
                                                        stratify=y, 
                                                        random_state=42)

    dict_split[sumber] = {
        'X_train': X_train,
        'X_test': X_test,
        'y_train': y_train,
        'y_test': y_test
    }

# %%
# %matplotlib inline
# Plot Label
x_list = []
y_list = []
title_list = []
for i, (sumber, item) in enumerate(dict_split.items()):
    num_train = len(item['X_train'])
    num_test = len(item['X_test'])

    label_texts = ["Training", "Testing"]
    label_values = [num_train, num_test]
    
    title_list.extend([f"PLOT PEMBAGIAN DATASET {i + 1}"])
    x_list.append(label_texts)
    y_list.append(label_values)
myplot.bar_plot_grid(x_list=x_list, y_list=y_list, title_list=title_list)

# %% [markdown]
# # 4. KLASIFIKASI
# ___

# %% [markdown]
# ## KLASIFIKASI MACHINE LEARNING
# ___

# %% [markdown]
# ### Training Model

# %% [markdown]
# #### Fungsi Training

# %%
# =====================================================
# Fungsi: melakukan training model
# =====================================================
def training_model_ml(X, y, model_name, save_model=False, params=None):
    if params is None:
        params = {}

    model_name = model_name.lower()

    # Mapping model singkat → tuple (butuh_scaling, constructor)
    model_map = {
        "svm": (True, SVC),
        "svc": (True, SVC),
        "knn": (True, KNeighborsClassifier),
        "mlp": (True, MLPClassifier),
        "neural": (True, MLPClassifier),
        "logreg": (True, LogisticRegression),
        "logisticregression": (True, LogisticRegression),
        "rf": (False, RandomForestClassifier),
        "randomforest": (False, RandomForestClassifier),
    }

    if model_name not in model_map:
        raise ValueError(f"Model '{model_name}' tidak dikenali!")

    use_scaler, ModelClass = model_map[model_name]

    # Buat pipeline jika perlu scaling
    if use_scaler:
        model = Pipeline([
            ("scaler", StandardScaler()),
            ("model", ModelClass(**params))
        ])
    else:
        model = ModelClass(**params)

    model = clone(model)
    model.fit(X, y)

    # Save model
    if save_model:
        with open(save_model, "wb") as f:
            pickle.dump(model, f)

    return model

# %% [markdown]
# #### Proses Training

# %%
# Nama Model : Parameter
models_ml = {
    "SVM": {'probability': True, 'random_state':42},
    "KNN": {},
    "RandomForest": {'random_state':42},
    "LogisticRegression": {'random_state':42},
    "MLP": {'random_state':42, 'max_iter':2000}
}

# %%
# Mulai timer
timer = mytimer.loop_timer()
next(timer)

total_iterasi = len(models_ml) * len(dict_split)
current_iter = 0
time_list = []

# Proses Training Semua Model
for model_name, params in models_ml.items():
    for sumber, dsplit in dict_split.items():
        # Hitung waktu satu iterasi (start)
        dt = timer.send("tick")
        if dt is not None:
            time_list.append(dt)
        # update posisi iterasi
        current_iter += 1

        # =================================================================================

        # Lokasi file model yang akan disimpan
        save_model = os.path.join(PATH_FOLDER['path_model_b'], sumber, f"{model_name}.pkl")

        # Ambil dataset train
        X_train = np.array(dsplit['X_train'])
        y_train = np.array(dsplit['y_train'])

        print(f"\n[{current_iter}/{total_iterasi}] Proses Training Model\t: {model_name}")
        print(f"      Sumber Dataset\t\t: {sumber}")

        # Proses Training Model ML
        model = training_model_ml(X=X_train, 
                                  y=y_train,
                                  model_name=model_name, 
                                  save_model=save_model,
                                  params=params)
        
        # Menghitung Akurasi
        y_pred = model.predict(X_train)
        acc = accuracy_score(y_train, y_pred)

        print(f"      Akurasi\t\t\t: {acc}")
        print(f"      Model disimpan\t\t: {save_model}")
        # =================================================================================
        print(f"      Waktu iterasi\t\t: {dt:.4f} detik")

    

# Akhiri timer (ambil total waktu)
info = timer.send("done")

# Tambahkan rata-rata waktu
info["avg_time"] = sum(time_list) / len(time_list)

print("\n======================")
print("       RINGKASAN     ")
print("======================")
print(f"Total iterasi : {total_iterasi}")
print(f"Total waktu   : {info['total_time']:.4f} detik")
print(f"Rata-rata per iterasi : {info['avg_time']:.4f} detik")
# Out:
# [1/5] Proses Training Model	: SVM
#       Sumber Dataset		: dataset_1
#       Akurasi			: 0.96875
#       Model disimpan		: Model_B\dataset_1\SVM.pkl
#       Waktu iterasi		: 0.0010 detik
#
# [2/5] Proses Training Model	: KNN
#       Sumber Dataset		: dataset_1
#       Akurasi			: 0.78125
#       Model disimpan		: Model_B\dataset_1\KNN.pkl
#       Waktu iterasi		: 0.0150 detik
#
# [3/5] Proses Training Model	: RandomForest
#       Sumber Dataset		: dataset_1
#       Akurasi			: 1.0
#       Model disimpan		: Model_B\dataset_1\RandomForest.pkl
#       Waktu iterasi		: 1.6027 detik
#
# [4/5] Proses Training Model	: LogisticRegression
#       Sumber Dataset		: dataset_1
#       Akurasi			: 1.0
#       Model disimpan		: Model_B\dataset_1\LogisticRegression.pkl
#       Waktu iterasi		: 0.1506 detik
#
# [5/5] Proses Training Model	: MLP
#       Sumber Dataset		: dataset_1
#       Akurasi			: 1.0
#       Model disimpan		: Model_B\dataset_1\MLP.pkl
#       Waktu iterasi		: 0.0110 detik
#
# ======================
#        RINGKASAN
# ======================
# Total iterasi : 5
# Total waktu   : 1.8870 detik
# Rata-rata per iterasi : 0.3561 detik

# %% [markdown]
# ## KLASIFIKASI DEEP LEARNING
# ___

# %% [markdown]
# ### Mengubah format menjadi Tensor

# %%
def convert_dataframe_to_tensor(df, model_type="efficientnet_b0", base_path="", image_size=(224, 224), batch_size=16):
    model_type_low = model_type.lower()
    # Lokasi File
    file_paths = df["LOKASI_GAMBAR"].apply(lambda x: os.path.join(base_path, x)).tolist()
    # Label
    labels = df["LABEL"].astype("float32").tolist()

    ds = tf.data.Dataset.from_tensor_slices((file_paths, labels))

    # Pilih preprocess_input sesuai model
    if model_type_low.startswith("efficientnet"):
        from tensorflow.keras.applications.efficientnet import preprocess_input
    elif model_type_low.startswith("resnet"):
        from tensorflow.keras.applications.resnet import preprocess_input
    elif model_type_low.startswith("mobilenet_v3"):
        from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
    else:
        raise ValueError(f"{model_type} tidak dikenal")

    def load_image(path, label):
        image = tf.io.read_file(path)
        image = tf.image.decode_png(image, channels=3)
        image = tf.image.resize(image, image_size)
        image = preprocess_input(image)
        return image, label

    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### Model

# %%
def build_modern_cnn(model_name="mobilenet_v3", 
                    image_size = (224, 224),
                    num_classes=1,
                    train_base=False):

    input_shape = (*image_size, 3)

    model_key = model_name.lower()

    # ===== Pilih Backbone Ringkas =====
    backbones = {
        "efficientnet_b0": tf.keras.applications.EfficientNetB0,
        "resnet50": tf.keras.applications.ResNet50,
        "mobilenet_v3": tf.keras.applications.MobileNetV3Small,
    }

    if model_key == "efficientnet_b0":
        # Download Manual Weights
        path = tf.keras.utils.get_file("efficientnetb0_notop.h5", origin="https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5")
        # Build model tanpa weights
        base_model = backbones[model_key](
            include_top=False,
            weights=None,
            input_shape=input_shape
        )

        # Load weights manual
        base_model.load_weights(path)

    elif model_key in ['resnet50', 'mobilenet_v3']:
        # Build model
        base_model = backbones[model_key](
            include_top=False,
            weights="imagenet",
            input_shape=input_shape
        )

    else:
        raise ValueError(f"Backbone tidak dikenal: {model_name}")


    # Freeze / Unfreeze backbone
    base_model.trainable = train_base

    # BANGUN MODEL
    # Input Layer
    inputs = tf.keras.layers.Input(shape=input_shape)
    # Backbone CNN tanpa train ulang
    x = base_model(inputs, training=train_base) 
    # Pooling: menonjolkan fitur paling kuat
    x = tf.keras.layers.GlobalMaxPool2D()(x)   
    # dropout untuk mengurangi overfitting         
    x = tf.keras.layers.Dropout(0.3)(x)                         

    # OUTPUT: Binary atau Multiclass
    if num_classes == 1:
        # Sigmoid untuk klasifikasi binary (0/1)
        outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
        loss = "binary_crossentropy"
    else:
        # Softmax untuk multi-class
        outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
        loss = "categorical_crossentropy"

    # Bangun model
    model = tf.keras.models.Model(inputs, outputs)

    # Kompilasi model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss=loss,  
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc"),
            tf.keras.metrics.Recall(name="sensitivity"),
            tf.keras.metrics.Precision(name="precision"),
        ]
    )

    return model

# %% [markdown]
# ### Callback

# %%
class TestMetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, test_ds, best_model_path, monitor="val_auc", mode="max"):
        super().__init__()
        self.test_ds = test_ds
        self.best_model_path = best_model_path
        self.monitor = monitor
        self.mode = mode

        self.best = -np.inf if mode == "max" else np.inf
        self.best_epoch = None
        self.history = []

    def on_epoch_begin(self, epoch, logs=None):
        print("_" * 100)
        print(f"\n Epoch {epoch + 1} Mulai")
        print("_" * 100)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current = logs.get(self.monitor)

        if current is None:
            return

        improved = (
            current > self.best if self.mode == "max"
            else current < self.best
        )

        if not improved:
            return
        
        # Update best
        self.best = current
        self.best_epoch = epoch + 1

        print(f"\nModel Terbaik → Evaluasi pada TEST set")

        results = self.model.evaluate(
            self.test_ds,
            verbose=1,
            return_dict=True
        )

        self.history.append({
            "epoch": self.best_epoch,
            **results
        })

        print(f"\nModel Terbaik → Evaluasi pada VAL set")

    def on_train_end(self, logs=None):
        print("_" * 50)
        print("\nTraining selesai.")
        print(f"\nHasil Epoch Terbaik {self.best_epoch} → Evaluasi Hasil Akhir Terbaik pada TEST set")

        # Load model terbaik dari ModelCheckpoint
        best_model = tf.keras.models.load_model(self.best_model_path)

        results = best_model.evaluate(
            self.test_ds,
            verbose=1,
            return_dict=True
        )
        
        print("_" * 50)


def build_callbacks(model_path, test_ds):
    callbacks = [

        # Hentikan training bila val_loss tidak membaik
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",       # metrik yang dipantau
            patience=6,              # berhenti jika 6 epoch tidak membaik
            restore_best_weights=True,
            verbose=1
        ),

        # Simpan model terbaik berdasarkan val_loss
        tf.keras.callbacks.ModelCheckpoint(
            filepath=model_path,
            monitor="val_loss",
            mode="min",
            save_best_only=True,     # hanya model terbaik yang disimpan
            save_weights_only=False,
            verbose=1
        ),

        # Uji otomatis pada test set
        TestMetricsCallback(
            test_ds,
            best_model_path=model_path,
            monitor="val_loss",
            mode="min"
        )
    ]

    return callbacks

# %% [markdown]
# ### Proses Training

# %%
models_dl = ["EfficientNet_B0", "ResNet50", "MobileNet_v3"]

# Mulai timer
timer = mytimer.loop_timer()
next(timer)

total_iterasi = len(models_dl) * len(dict_split)
current_iter = 0
time_list = []

# Proses Training Semua Model
for model_name in models_dl:
    for sumber, dsplit in dict_split.items():
        current_iter += 1
        # =================================================================================
        print("\n")
        print("=" * 120)
        print("=" * 120)
        print(f"[{current_iter}/{total_iterasi}] Proses Training Model\t: {model_name}")
        print(f"      Sumber Dataset\t\t: {sumber}")
        
        # Lokasi File Model Baru
        save_model = os.path.join(
            PATH_FOLDER['path_model_b'], sumber, f"{model_name}.keras"
        )
        save_model_history = os.path.join(
            PATH_FOLDER['path_model_b'], sumber, f"history_{model_name}.pkl"
        )

        if os.path.exists(save_model):
            os.remove(save_model)
        if os.path.exists(save_model_history):
            os.remove(save_model_history)

        # Mengambil dataset hasil pembagian didalam dict_split
        idx_train = dsplit['X_train'].index.tolist()
        idx_test = dsplit['X_test'].index.tolist()

        df_train, df_val = train_test_split(
            df.iloc[idx_train],
            train_size=0.8,
            random_state=42,
            stratify=df.iloc[idx_train]["LABEL"]
        )
        df_test = df.iloc[idx_test]

        # Ubah data menjadi tensor
        # Data Training
        train_ds = convert_dataframe_to_tensor(
            df=df_train,
            base_path=PATH_FOLDER['dataset_extract_b'],
            image_size=IMAGE_SIZE
        )
        
        # Data Validation
        val_ds = convert_dataframe_to_tensor(
            df=df_val,
            base_path=PATH_FOLDER['dataset_extract_b'],
            image_size=IMAGE_SIZE
        )
        # Data Testing
        test_ds = convert_dataframe_to_tensor(
            df=df_test,
            base_path=PATH_FOLDER['dataset_extract_b'],
            image_size=IMAGE_SIZE
        )

        print(f"      Data Training\t\t: {len(df_train)}")
        print(f"      Data Validation\t\t: {len(df_val)}")
        print(f"      Data Testing\t\t: {len(df_test)}")
        print("=" * 120)
        print("=" * 120)
        # Model
        model = build_modern_cnn(model_name=model_name, image_size=IMAGE_SIZE)

        # Summary
        print(model.summary())

        # Callback
        callbacks = build_callbacks(
            model_path=save_model, 
            test_ds=test_ds
        )

        # Proses Training Model
        history = model.fit(
            train_ds, 
            validation_data=val_ds,
            epochs=100, 
            callbacks=callbacks,
            verbose=1
        )
        
        # Simpan history training CNN
        history_dict = history.history.copy()

        # Tambahkan evaluasi TEST (hanya saat model terbaik)
        history_dict['test_history'] = callbacks[-1].history
        history_dict['best_epoch'] = callbacks[-1].best_epoch

        # Simpan File
        with open(save_model_history, 'wb') as f:
            pickle.dump(history_dict, f)
        
        # =================================================
        # Hitung waktu iterasi
        # =================================================
        dt = timer.send("tick")
        if dt is not None:
            time_list.append(dt)
        print(f"\n Waktu iterasi: {mytimer.format_time(dt)}")
        print("_" * 50)

    

# =====================================================
# Akhiri timer dan hitung rata-rata waktu
# =====================================================
info = timer.send("done")
info["avg_time"] = sum(time_list) / len(time_list)

# =====================================================
# Tampilkan Ringkasan
# =====================================================
print("\n======================")
print("       RINGKASAN     ")
print("======================")
print(f"Total iterasi            : {total_iterasi}")
print(f"Total waktu              : {mytimer.format_time(info['total_time'])}")
print(f"Rata-rata waktu/iterasi  : {mytimer.format_time(info['avg_time'])}")
# Out:
# ========================================================================================================================
# ========================================================================================================================
# [1/3] Proses Training Model	: EfficientNet_B0
#       Sumber Dataset		: dataset_1
#       Data Training		: 25
#       Data Validation		: 7
#       Data Testing		: 8
# ========================================================================================================================
# ========================================================================================================================
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d            │ (None, 1280)           │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,050,852 (15.45 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)
# None
# ____________________________________________________________________________________________________
#
#  Epoch 1 Mulai
# ____________________________________________________________________________________________________
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.4387 - auc: 0.4567 - loss: 3.0896 - precision: 0.0000e+00 - sensitivity: 0.0000e+00
# Epoch 1: val_loss improved from None to 1.67897, saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Epoch 1: finished saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.5000 - auc: 0.3125 - loss: 1.7498 - precision: 0.0000e+00 - sensitivity: 0.0000e+00
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step - accuracy: 0.4400 - auc: 0.4135 - loss: 2.9245 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - val_accuracy: 0.5714 - val_auc: 0.1667 - val_loss: 1.6790 - val_precision: 0.0000e+00 - val_sensitivity: 0.0000e+00
# ____________________________________________________________________________________________________
#
#  Epoch 2 Mulai
# ____________________________________________________________________________________________________
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4075 - auc: 0.3055 - loss: 2.0886 - precision: 0.0000e+00 - sensitivity: 0.0000e+00
# Epoch 2: val_loss improved from 1.67897 to 0.89110, saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Epoch 2: finished saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.3750 - auc: 0.5000 - loss: 0.6973 - precision: 0.4000 - sensitivity: 0.5000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.4400 - auc: 0.3173 - loss: 1.9131 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - val_accuracy: 0.4286 - val_auc: 0.1667 - val_loss: 0.8911 - val_precision: 0.3333 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 3 Mulai
# ____________________________________________________________________________________________________
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4900 - auc: 0.4035 - loss: 1.3022 - precision: 0.5357 - sensitivity: 0.4915
# Epoch 3: val_loss did not improve from 0.89110
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step - accuracy: 0.4800 - auc: 0.4103 - loss: 1.3180 - precision: 0.5000 - sensitivity: 0.5385 - val_accuracy: 0.4286 - val_auc: 0.2500 - val_loss: 1.5216 - val_precision: 0.4286 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 4 Mulai
# ____________________________________________________________________________________________________
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.5925 - auc: 0.5424 - loss: 1.1491 - precision: 0.5727 - sensitivity: 0.9615
# Epoch 4: val_loss did not improve from 0.89110
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.5600 - auc: 0.5769 - loss: 1.1372 - precision: 0.5455 - sensitivity: 0.9231 - val_accuracy: 0.4286 - val_auc: 0.5833 - val_loss: 1.7591 - val_precision: 0.4286 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 5 Mulai
# ____________________________________________________________________________________________________
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.6125 - auc: 0.6771 - loss: 1.2697 - precision: 0.5934 - sensitivity: 0.9060
# Epoch 5: val_loss did not improve from 0.89110
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 450ms/step - accuracy: 0.6000 - auc: 0.6955 - loss: 1.1770 - precision: 0.5714 - sensitivity: 0.9231 - val_accuracy: 0.4286 - val_auc: 0.6250 - val_loss: 1.5014 - val_precision: 0.4286 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 6 Mulai
# ____________________________________________________________________________________________________
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.5925 - auc: 0.6006 - loss: 1.4350 - precision: 0.5827 - sensitivity: 0.8675
# Epoch 6: val_loss did not improve from 0.89110
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 372ms/step - accuracy: 0.5600 - auc: 0.6218 - loss: 1.4794 - precision: 0.5500 - sensitivity: 0.8462 - val_accuracy: 0.4286 - val_auc: 0.6667 - val_loss: 1.0157 - val_precision: 0.4286 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 7 Mulai
# ____________________________________________________________________________________________________
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.4900 - auc: 0.5465 - loss: 1.1932 - precision: 0.5167 - sensitivity: 0.8291
# Epoch 7: val_loss improved from 0.89110 to 0.61016, saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Epoch 7: finished saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7500 - auc: 0.6875 - loss: 0.5818 - precision: 0.7500 - sensitivity: 0.7500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.4800 - auc: 0.5929 - loss: 1.1143 - precision: 0.5000 - sensitivity: 0.7692 - val_accuracy: 0.7143 - val_auc: 0.6667 - val_loss: 0.6102 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 8 Mulai
# ____________________________________________________________________________________________________
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7237 - auc: 0.8781 - loss: 0.4467 - precision: 0.7841 - sensitivity: 0.6795
# Epoch 8: val_loss improved from 0.61016 to 0.54759, saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Epoch 8: finished saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7500 - auc: 0.6875 - loss: 0.6818 - precision: 1.0000 - sensitivity: 0.5000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.7600 - auc: 0.9071 - loss: 0.4145 - precision: 0.8182 - sensitivity: 0.6923 - val_accuracy: 0.7143 - val_auc: 0.6667 - val_loss: 0.5476 - val_precision: 1.0000 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 9 Mulai
# ____________________________________________________________________________________________________
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6725 - auc: 0.7721 - loss: 0.6996 - precision: 0.7571 - sensitivity: 0.5855
# Epoch 9: val_loss did not improve from 0.54759
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 378ms/step - accuracy: 0.7200 - auc: 0.8141 - loss: 0.6414 - precision: 0.8000 - sensitivity: 0.6154 - val_accuracy: 0.7143 - val_auc: 0.8333 - val_loss: 0.5595 - val_precision: 1.0000 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 10 Mulai
# ____________________________________________________________________________________________________
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7663 - auc: 0.8253 - loss: 0.5986 - precision: 0.9375 - sensitivity: 0.6026
# Epoch 10: val_loss improved from 0.54759 to 0.50494, saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Epoch 10: finished saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7500 - auc: 0.7188 - loss: 0.7544 - precision: 1.0000 - sensitivity: 0.5000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.7200 - auc: 0.8173 - loss: 0.6646 - precision: 0.8750 - sensitivity: 0.5385 - val_accuracy: 0.7143 - val_auc: 0.9167 - val_loss: 0.5049 - val_precision: 1.0000 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 11 Mulai
# ____________________________________________________________________________________________________
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7550 - auc: 0.8619 - loss: 0.7579 - precision: 1.0000 - sensitivity: 0.5470
# Epoch 11: val_loss improved from 0.50494 to 0.41098, saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Epoch 11: finished saving model to Model_B\dataset_1\EfficientNet_B0.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.7500 - auc: 0.8125 - loss: 0.6012 - precision: 1.0000 - sensitivity: 0.5000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.7600 - auc: 0.8269 - loss: 0.8491 - precision: 1.0000 - sensitivity: 0.5385 - val_accuracy: 0.8571 - val_auc: 1.0000 - val_loss: 0.4110 - val_precision: 1.0000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 12 Mulai
# ____________________________________________________________________________________________________
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7350 - auc: 0.8404 - loss: 0.5744 - precision: 0.7639 - sensitivity: 0.7350
# Epoch 12: val_loss did not improve from 0.41098
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 393ms/step - accuracy: 0.7200 - auc: 0.8077 - loss: 0.6695 - precision: 0.7500 - sensitivity: 0.6923 - val_accuracy: 0.7143 - val_auc: 1.0000 - val_loss: 0.4201 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 13 Mulai
# ____________________________________________________________________________________________________
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9800 - auc: 0.9968 - loss: 0.1443 - precision: 1.0000 - sensitivity: 0.9615
# Epoch 13: val_loss did not improve from 0.41098
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 390ms/step - accuracy: 0.9600 - auc: 0.9936 - loss: 0.1548 - precision: 1.0000 - sensitivity: 0.9231 - val_accuracy: 0.7143 - val_auc: 1.0000 - val_loss: 0.5189 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 14 Mulai
# ____________________________________________________________________________________________________
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9087 - auc: 0.9489 - loss: 0.3563 - precision: 0.8786 - sensitivity: 0.9615
# Epoch 14: val_loss did not improve from 0.41098
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step - accuracy: 0.8800 - auc: 0.9295 - loss: 0.4031 - precision: 0.8571 - sensitivity: 0.9231 - val_accuracy: 0.5714 - val_auc: 1.0000 - val_loss: 0.6167 - val_precision: 0.5000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 15 Mulai
# ____________________________________________________________________________________________________
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8462 - auc: 0.9426 - loss: 0.3562 - precision: 0.7812 - sensitivity: 1.0000
# Epoch 15: val_loss did not improve from 0.41098
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 390ms/step - accuracy: 0.8800 - auc: 0.9487 - loss: 0.3388 - precision: 0.8125 - sensitivity: 1.0000 - val_accuracy: 0.5714 - val_auc: 1.0000 - val_loss: 0.6312 - val_precision: 0.5000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 16 Mulai
# ____________________________________________________________________________________________________
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7550 - auc: 0.9409 - loss: 0.4742 - precision: 0.6991 - sensitivity: 0.9615
# Epoch 16: val_loss did not improve from 0.41098
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 407ms/step - accuracy: 0.7600 - auc: 0.9295 - loss: 0.4517 - precision: 0.7059 - sensitivity: 0.9231 - val_accuracy: 0.7143 - val_auc: 1.0000 - val_loss: 0.5494 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 17 Mulai
# ____________________________________________________________________________________________________
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7750 - auc: 0.9203 - loss: 0.3993 - precision: 0.8056 - sensitivity: 0.7735
# Epoch 17: val_loss did not improve from 0.41098
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 423ms/step - accuracy: 0.8000 - auc: 0.9359 - loss: 0.3487 - precision: 0.8333 - sensitivity: 0.7692 - val_accuracy: 0.7143 - val_auc: 1.0000 - val_loss: 0.4759 - val_precision: 0.6000 - val_sensitivity: 1.0000
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 11.
# __________________________________________________
#
# Training selesai.
#
# Hasil Epoch Terbaik 11 → Evaluasi Hasil Akhir Terbaik pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.7500 - auc: 0.8125 - loss: 0.6012 - precision: 1.0000 - sensitivity: 0.5000
# __________________________________________________
#
#  Waktu iterasi: 44 detik
# __________________________________________________
#
#
# ========================================================================================================================
# ========================================================================================================================
# [2/3] Proses Training Model	: ResNet50
#       Sumber Dataset		: dataset_1
#       Data Training		: 25
#       Data Validation		: 7
#       Data Testing		: 8
# ========================================================================================================================
# ========================================================================================================================
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d_1          │ (None, 2048)           │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         2,049 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,589,761 (89.99 MB)
#  Trainable params: 2,049 (8.00 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# None
# ____________________________________________________________________________________________________
#
#  Epoch 1 Mulai
# ____________________________________________________________________________________________________
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.6637 - auc: 0.6443 - loss: 1.2653 - precision: 0.7000 - sensitivity: 0.6581
# Epoch 1: val_loss improved from None to 0.48487, saving model to Model_B\dataset_1\ResNet50.keras
#
# Epoch 1: finished saving model to Model_B\dataset_1\ResNet50.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.6250 - auc: 0.4375 - loss: 0.9876 - precision: 1.0000 - sensitivity: 0.2500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 6s/step - accuracy: 0.6400 - auc: 0.6378 - loss: 1.3472 - precision: 0.7000 - sensitivity: 0.5385 - val_accuracy: 0.7143 - val_auc: 0.8333 - val_loss: 0.4849 - val_precision: 0.6667 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 2 Mulai
# ____________________________________________________________________________________________________
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.6325 - auc: 0.6086 - loss: 1.0393 - precision: 0.6667 - sensitivity: 0.6410
# Epoch 2: val_loss improved from 0.48487 to 0.45410, saving model to Model_B\dataset_1\ResNet50.keras
#
# Epoch 2: finished saving model to Model_B\dataset_1\ResNet50.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.5000 - auc: 0.4375 - loss: 0.6966 - precision: 0.5000 - sensitivity: 0.7500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 3s/step - accuracy: 0.6400 - auc: 0.6378 - loss: 0.9872 - precision: 0.6667 - sensitivity: 0.6154 - val_accuracy: 0.8571 - val_auc: 0.9167 - val_loss: 0.4541 - val_precision: 0.7500 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 3 Mulai
# ____________________________________________________________________________________________________
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.5500 - auc: 0.5250 - loss: 1.2145 - precision: 0.5855 - sensitivity: 0.5855
# Epoch 3: val_loss improved from 0.45410 to 0.40037, saving model to Model_B\dataset_1\ResNet50.keras
#
# Epoch 3: finished saving model to Model_B\dataset_1\ResNet50.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.6250 - auc: 0.7500 - loss: 0.6426 - precision: 0.5714 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.6000 - auc: 0.5897 - loss: 1.0565 - precision: 0.6154 - sensitivity: 0.6154 - val_accuracy: 0.8571 - val_auc: 1.0000 - val_loss: 0.4004 - val_precision: 0.7500 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 4 Mulai
# ____________________________________________________________________________________________________
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.7663 - auc: 0.7055 - loss: 0.8762 - precision: 0.8375 - sensitivity: 0.6966
# Epoch 4: val_loss did not improve from 0.40037
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 762ms/step - accuracy: 0.7200 - auc: 0.6571 - loss: 1.1185 - precision: 0.8000 - sensitivity: 0.6154 - val_accuracy: 0.7143 - val_auc: 1.0000 - val_loss: 0.4720 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 5 Mulai
# ____________________________________________________________________________________________________
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.6838 - auc: 0.8085 - loss: 0.9528 - precision: 0.6491 - sensitivity: 0.9060
# Epoch 5: val_loss improved from 0.40037 to 0.21199, saving model to Model_B\dataset_1\ResNet50.keras
#
# Epoch 5: finished saving model to Model_B\dataset_1\ResNet50.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.6250 - auc: 0.8750 - loss: 0.5576 - precision: 0.5714 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - accuracy: 0.6800 - auc: 0.7756 - loss: 1.0692 - precision: 0.6316 - sensitivity: 0.9231 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.2120 - val_precision: 1.0000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 6 Mulai
# ____________________________________________________________________________________________________
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.8575 - auc: 0.8644 - loss: 0.5626 - precision: 0.8091 - sensitivity: 0.9615
# Epoch 6: val_loss improved from 0.21199 to 0.11348, saving model to Model_B\dataset_1\ResNet50.keras
#
# Epoch 6: finished saving model to Model_B\dataset_1\ResNet50.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.7500 - auc: 0.8750 - loss: 0.4353 - precision: 0.7500 - sensitivity: 0.7500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - accuracy: 0.8400 - auc: 0.8558 - loss: 0.5992 - precision: 0.8000 - sensitivity: 0.9231 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1135 - val_precision: 1.0000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 7 Mulai
# ____________________________________________________________________________________________________
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8887 - auc: 0.9552 - loss: 0.4321 - precision: 1.0000 - sensitivity: 0.7906
# Epoch 7: val_loss did not improve from 0.11348
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 785ms/step - accuracy: 0.8400 - auc: 0.9263 - loss: 0.6133 - precision: 1.0000 - sensitivity: 0.6923 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1189 - val_precision: 1.0000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 8 Mulai
# ____________________________________________________________________________________________________
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8262 - auc: 0.8566 - loss: 0.5867 - precision: 1.0000 - sensitivity: 0.6795
# Epoch 8: val_loss improved from 0.11348 to 0.09258, saving model to Model_B\dataset_1\ResNet50.keras
#
# Epoch 8: finished saving model to Model_B\dataset_1\ResNet50.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.7500 - auc: 0.8750 - loss: 0.4158 - precision: 0.7500 - sensitivity: 0.7500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 5s/step - accuracy: 0.8400 - auc: 0.8878 - loss: 0.5085 - precision: 1.0000 - sensitivity: 0.6923 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0926 - val_precision: 1.0000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 9 Mulai
# ____________________________________________________________________________________________________
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8887 - auc: 0.9777 - loss: 0.2220 - precision: 1.0000 - sensitivity: 0.7906
# Epoch 9: val_loss did not improve from 0.09258
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 777ms/step - accuracy: 0.8400 - auc: 0.9872 - loss: 0.2492 - precision: 1.0000 - sensitivity: 0.6923 - val_accuracy: 0.8571 - val_auc: 1.0000 - val_loss: 0.1443 - val_precision: 0.7500 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 10 Mulai
# ____________________________________________________________________________________________________
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9800 - auc: 1.0000 - loss: 0.0681 - precision: 0.9643 - sensitivity: 1.0000
# Epoch 10: val_loss did not improve from 0.09258
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step - accuracy: 0.9600 - auc: 1.0000 - loss: 0.0819 - precision: 0.9286 - sensitivity: 1.0000 - val_accuracy: 0.8571 - val_auc: 1.0000 - val_loss: 0.3181 - val_precision: 0.7500 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 11 Mulai
# ____________________________________________________________________________________________________
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0805 - precision: 1.0000 - sensitivity: 1.0000
# Epoch 11: val_loss did not improve from 0.09258
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 803ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0922 - precision: 1.0000 - sensitivity: 1.0000 - val_accuracy: 0.7143 - val_auc: 1.0000 - val_loss: 0.4884 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 12 Mulai
# ____________________________________________________________________________________________________
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.7950 - auc: 0.9904 - loss: 0.3625 - precision: 0.7285 - sensitivity: 1.0000
# Epoch 12: val_loss did not improve from 0.09258
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step - accuracy: 0.8400 - auc: 0.9808 - loss: 0.3062 - precision: 0.7647 - sensitivity: 1.0000 - val_accuracy: 0.7143 - val_auc: 1.0000 - val_loss: 0.4502 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 13 Mulai
# ____________________________________________________________________________________________________
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0367 - precision: 1.0000 - sensitivity: 1.0000
# Epoch 13: val_loss did not improve from 0.09258
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0353 - precision: 1.0000 - sensitivity: 1.0000 - val_accuracy: 0.7143 - val_auc: 1.0000 - val_loss: 0.4158 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 14 Mulai
# ____________________________________________________________________________________________________
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9288 - auc: 0.9904 - loss: 0.1342 - precision: 0.9115 - sensitivity: 0.9615
# Epoch 14: val_loss did not improve from 0.09258
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 785ms/step - accuracy: 0.9200 - auc: 0.9808 - loss: 0.1907 - precision: 0.9231 - sensitivity: 0.9231 - val_accuracy: 0.7143 - val_auc: 1.0000 - val_loss: 0.4163 - val_precision: 0.6000 - val_sensitivity: 1.0000
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 8.
# __________________________________________________
#
# Training selesai.
#
# Hasil Epoch Terbaik 8 → Evaluasi Hasil Akhir Terbaik pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.7500 - auc: 0.8750 - loss: 0.4158 - precision: 0.7500 - sensitivity: 0.7500
# __________________________________________________
#
#  Waktu iterasi: 57 detik
# __________________________________________________
#
#
# ========================================================================================================================
# ========================================================================================================================
# [3/3] Proses Training Model	: MobileNet_v3
#       Sumber Dataset		: dataset_1
#       Data Training		: 25
#       Data Validation		: 7
#       Data Testing		: 8
# ========================================================================================================================
# ========================================================================================================================
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV3Small (Functional)   │ (None, 7, 7, 576)      │       939,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d_2          │ (None, 576)            │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 939,697 (3.58 MB)
#  Trainable params: 577 (2.25 KB)
#  Non-trainable params: 939,120 (3.58 MB)
# None
# ____________________________________________________________________________________________________
#
#  Epoch 1 Mulai
# ____________________________________________________________________________________________________
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4275 - auc: 0.5202 - loss: 3.5178 - precision: 0.2500 - sensitivity: 0.0385
# Epoch 1: val_loss improved from None to 2.62315, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 1: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6250 - auc: 0.6875 - loss: 1.7359 - precision: 1.0000 - sensitivity: 0.2500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4800 - auc: 0.5801 - loss: 3.3609 - precision: 0.5000 - sensitivity: 0.0769 - val_accuracy: 0.5714 - val_auc: 0.3333 - val_loss: 2.6231 - val_precision: 0.0000e+00 - val_sensitivity: 0.0000e+00
# ____________________________________________________________________________________________________
#
#  Epoch 2 Mulai
# ____________________________________________________________________________________________________
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4587 - auc: 0.5892 - loss: 2.6955 - precision: 0.5000 - sensitivity: 0.1325
# Epoch 2: val_loss improved from 2.62315 to 1.43554, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 2: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - auc: 0.7500 - loss: 0.8068 - precision: 0.5000 - sensitivity: 0.2500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step - accuracy: 0.4800 - auc: 0.5673 - loss: 2.5226 - precision: 0.5000 - sensitivity: 0.1538 - val_accuracy: 0.2857 - val_auc: 0.3333 - val_loss: 1.4355 - val_precision: 0.0000e+00 - val_sensitivity: 0.0000e+00
# ____________________________________________________________________________________________________
#
#  Epoch 3 Mulai
# ____________________________________________________________________________________________________
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5700 - auc: 0.5913 - loss: 1.4678 - precision: 0.6190 - sensitivity: 0.5299
# Epoch 3: val_loss improved from 1.43554 to 1.31378, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 3: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7500 - auc: 0.7500 - loss: 0.9280 - precision: 0.6667 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step - accuracy: 0.6400 - auc: 0.6667 - loss: 1.3581 - precision: 0.6667 - sensitivity: 0.6154 - val_accuracy: 0.4286 - val_auc: 0.3333 - val_loss: 1.3138 - val_precision: 0.3333 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 4 Mulai
# ____________________________________________________________________________________________________
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5813 - auc: 0.6540 - loss: 1.6223 - precision: 0.5858 - sensitivity: 0.7735
# Epoch 4: val_loss did not improve from 1.31378
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.6000 - auc: 0.6731 - loss: 1.6162 - precision: 0.5882 - sensitivity: 0.7692 - val_accuracy: 0.4286 - val_auc: 0.3333 - val_loss: 1.5037 - val_precision: 0.4000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 5 Mulai
# ____________________________________________________________________________________________________
# Epoch 5/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6875 - auc: 0.6825 - loss: 1.1859 - precision: 0.6667 - sensitivity: 0.8889
# Epoch 5: val_loss did not improve from 1.31378
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6400 - auc: 0.6635 - loss: 1.2840 - precision: 0.6250 - sensitivity: 0.7692 - val_accuracy: 0.2857 - val_auc: 0.3333 - val_loss: 1.5584 - val_precision: 0.3333 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 6 Mulai
# ____________________________________________________________________________________________________
# Epoch 6/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5000 - auc: 0.6032 - loss: 2.0776 - precision: 0.5556 - sensitivity: 0.5556
# Epoch 6: val_loss did not improve from 1.31378
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5200 - auc: 0.6699 - loss: 1.6982 - precision: 0.5294 - sensitivity: 0.6923 - val_accuracy: 0.5714 - val_auc: 0.3333 - val_loss: 1.4783 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 7 Mulai
# ____________________________________________________________________________________________________
# Epoch 7/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5625 - auc: 0.6349 - loss: 1.6567 - precision: 0.5833 - sensitivity: 0.7778
# Epoch 7: val_loss improved from 1.31378 to 1.23645, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 7: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7500 - auc: 0.8125 - loss: 0.9398 - precision: 0.6667 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4000 - auc: 0.4968 - loss: 2.1495 - precision: 0.4444 - sensitivity: 0.6154 - val_accuracy: 0.5714 - val_auc: 0.5000 - val_loss: 1.2364 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 8 Mulai
# ____________________________________________________________________________________________________
# Epoch 8/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5000 - auc: 0.3413 - loss: 2.5875 - precision: 0.5455 - sensitivity: 0.6667
# Epoch 8: val_loss improved from 1.23645 to 1.07803, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 8: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8750 - auc: 0.8125 - loss: 0.7354 - precision: 0.8000 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step - accuracy: 0.5200 - auc: 0.4071 - loss: 2.3346 - precision: 0.5294 - sensitivity: 0.6923 - val_accuracy: 0.4286 - val_auc: 0.5000 - val_loss: 1.0780 - val_precision: 0.3333 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 9 Mulai
# ____________________________________________________________________________________________________
# Epoch 9/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6875 - auc: 0.6825 - loss: 1.4770 - precision: 0.7000 - sensitivity: 0.7778
# Epoch 9: val_loss improved from 1.07803 to 1.04381, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 9: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6250 - auc: 0.8125 - loss: 0.6934 - precision: 0.6667 - sensitivity: 0.5000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step - accuracy: 0.7600 - auc: 0.7788 - loss: 1.0256 - precision: 0.7333 - sensitivity: 0.8462 - val_accuracy: 0.4286 - val_auc: 0.5000 - val_loss: 1.0438 - val_precision: 0.3333 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 10 Mulai
# ____________________________________________________________________________________________________
# Epoch 10/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7500 - auc: 0.8095 - loss: 0.6536 - precision: 0.7778 - sensitivity: 0.7778
# Epoch 10: val_loss did not improve from 1.04381
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6400 - auc: 0.7308 - loss: 1.3270 - precision: 0.7000 - sensitivity: 0.5385 - val_accuracy: 0.4286 - val_auc: 0.5417 - val_loss: 1.0592 - val_precision: 0.3333 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 11 Mulai
# ____________________________________________________________________________________________________
# Epoch 11/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6875 - auc: 0.8889 - loss: 0.6516 - precision: 1.0000 - sensitivity: 0.4444
# Epoch 11: val_loss improved from 1.04381 to 1.01035, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 11: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6250 - auc: 0.8125 - loss: 0.7137 - precision: 0.6667 - sensitivity: 0.5000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - accuracy: 0.8000 - auc: 0.9455 - loss: 0.4496 - precision: 1.0000 - sensitivity: 0.6154 - val_accuracy: 0.4286 - val_auc: 0.5833 - val_loss: 1.0103 - val_precision: 0.3333 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 12 Mulai
# ____________________________________________________________________________________________________
# Epoch 12/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6250 - auc: 0.6984 - loss: 1.5847 - precision: 0.8000 - sensitivity: 0.4444
# Epoch 12: val_loss improved from 1.01035 to 0.94531, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 12: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6250 - auc: 0.8125 - loss: 0.6812 - precision: 0.6667 - sensitivity: 0.5000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step - accuracy: 0.5600 - auc: 0.6923 - loss: 1.5048 - precision: 0.6250 - sensitivity: 0.3846 - val_accuracy: 0.4286 - val_auc: 0.5833 - val_loss: 0.9453 - val_precision: 0.3333 - val_sensitivity: 0.3333
# ____________________________________________________________________________________________________
#
#  Epoch 13 Mulai
# ____________________________________________________________________________________________________
# Epoch 13/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6250 - auc: 0.6508 - loss: 1.1381 - precision: 0.6364 - sensitivity: 0.7778
# Epoch 13: val_loss improved from 0.94531 to 0.92888, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 13: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8750 - auc: 0.8125 - loss: 0.6900 - precision: 0.8000 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - accuracy: 0.7200 - auc: 0.7404 - loss: 0.9220 - precision: 0.7143 - sensitivity: 0.7692 - val_accuracy: 0.5714 - val_auc: 0.6667 - val_loss: 0.9289 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 14 Mulai
# ____________________________________________________________________________________________________
# Epoch 14/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6250 - auc: 0.6984 - loss: 0.7513 - precision: 0.6667 - sensitivity: 0.6667
# Epoch 14: val_loss did not improve from 0.92888
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5200 - auc: 0.5865 - loss: 1.4022 - precision: 0.5385 - sensitivity: 0.5385 - val_accuracy: 0.5714 - val_auc: 0.6667 - val_loss: 0.9535 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 15 Mulai
# ____________________________________________________________________________________________________
# Epoch 15/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5625 - auc: 0.5794 - loss: 1.8369 - precision: 0.6000 - sensitivity: 0.6667
# Epoch 15: val_loss did not improve from 0.92888
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6000 - auc: 0.6667 - loss: 1.6445 - precision: 0.6000 - sensitivity: 0.6923 - val_accuracy: 0.5714 - val_auc: 0.6667 - val_loss: 0.9594 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 16 Mulai
# ____________________________________________________________________________________________________
# Epoch 16/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9375 - auc: 0.9365 - loss: 0.3257 - precision: 0.9000 - sensitivity: 1.0000
# Epoch 16: val_loss improved from 0.92888 to 0.92886, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 16: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8750 - auc: 0.8125 - loss: 0.7482 - precision: 0.8000 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step - accuracy: 0.8800 - auc: 0.8718 - loss: 0.6456 - precision: 0.8571 - sensitivity: 0.9231 - val_accuracy: 0.5714 - val_auc: 0.6667 - val_loss: 0.9289 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 17 Mulai
# ____________________________________________________________________________________________________
# Epoch 17/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8125 - auc: 0.9524 - loss: 0.2482 - precision: 0.8750 - sensitivity: 0.7778
# Epoch 17: val_loss did not improve from 0.92886
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8000 - auc: 0.9231 - loss: 0.4512 - precision: 0.9000 - sensitivity: 0.6923 - val_accuracy: 0.5714 - val_auc: 0.6667 - val_loss: 0.9296 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 18 Mulai
# ____________________________________________________________________________________________________
# Epoch 18/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6875 - auc: 0.7063 - loss: 1.4462 - precision: 0.7000 - sensitivity: 0.7778
# Epoch 18: val_loss did not improve from 0.92886
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7600 - auc: 0.7917 - loss: 1.0315 - precision: 0.7692 - sensitivity: 0.7692 - val_accuracy: 0.5714 - val_auc: 0.6667 - val_loss: 0.9320 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 19 Mulai
# ____________________________________________________________________________________________________
# Epoch 19/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8750 - auc: 0.9048 - loss: 0.6531 - precision: 0.8182 - sensitivity: 1.0000
# Epoch 19: val_loss improved from 0.92886 to 0.89397, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 19: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8750 - auc: 0.8125 - loss: 0.7517 - precision: 0.8000 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step - accuracy: 0.9200 - auc: 0.9423 - loss: 0.4424 - precision: 0.8667 - sensitivity: 1.0000 - val_accuracy: 0.5714 - val_auc: 0.6667 - val_loss: 0.8940 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 20 Mulai
# ____________________________________________________________________________________________________
# Epoch 20/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6875 - auc: 0.7937 - loss: 0.9311 - precision: 0.7500 - sensitivity: 0.6667
# Epoch 20: val_loss improved from 0.89397 to 0.86846, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 20: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8750 - auc: 0.8125 - loss: 0.7396 - precision: 0.8000 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step - accuracy: 0.7600 - auc: 0.8237 - loss: 0.7652 - precision: 0.8182 - sensitivity: 0.6923 - val_accuracy: 0.5714 - val_auc: 0.6667 - val_loss: 0.8685 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 21 Mulai
# ____________________________________________________________________________________________________
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7950 - auc: 0.8614 - loss: 0.6229 - precision: 0.8831 - sensitivity: 0.7179
# Epoch 21: val_loss did not improve from 0.86846
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8400 - auc: 0.8974 - loss: 0.4977 - precision: 0.9091 - sensitivity: 0.7692 - val_accuracy: 0.5714 - val_auc: 0.6667 - val_loss: 0.8715 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 22 Mulai
# ____________________________________________________________________________________________________
# Epoch 22/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6875 - auc: 0.7857 - loss: 0.9349 - precision: 0.6667 - sensitivity: 0.8889
# Epoch 22: val_loss improved from 0.86846 to 0.84334, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 22: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8750 - auc: 0.8125 - loss: 0.7393 - precision: 0.8000 - sensitivity: 1.0000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - accuracy: 0.6800 - auc: 0.7308 - loss: 1.2350 - precision: 0.6667 - sensitivity: 0.7692 - val_accuracy: 0.5714 - val_auc: 0.7500 - val_loss: 0.8433 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 23 Mulai
# ____________________________________________________________________________________________________
# Epoch 23/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6875 - auc: 0.8095 - loss: 1.3075 - precision: 0.6667 - sensitivity: 0.8889
# Epoch 23: val_loss improved from 0.84334 to 0.78029, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 23: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7500 - auc: 0.8125 - loss: 0.7039 - precision: 0.7500 - sensitivity: 0.7500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 676ms/step - accuracy: 0.7200 - auc: 0.8333 - loss: 0.9910 - precision: 0.6875 - sensitivity: 0.8462 - val_accuracy: 0.5714 - val_auc: 0.7500 - val_loss: 0.7803 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 24 Mulai
# ____________________________________________________________________________________________________
# Epoch 24/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7500 - auc: 0.8175 - loss: 0.8890 - precision: 0.7273 - sensitivity: 0.8889
# Epoch 24: val_loss improved from 0.78029 to 0.71615, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 24: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7500 - auc: 0.8125 - loss: 0.6823 - precision: 0.7500 - sensitivity: 0.7500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - accuracy: 0.8000 - auc: 0.8686 - loss: 0.6217 - precision: 0.7500 - sensitivity: 0.9231 - val_accuracy: 0.5714 - val_auc: 0.7500 - val_loss: 0.7161 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 25 Mulai
# ____________________________________________________________________________________________________
# Epoch 25/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8750 - auc: 0.8889 - loss: 0.5078 - precision: 0.8182 - sensitivity: 1.0000
# Epoch 25: val_loss improved from 0.71615 to 0.67967, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 25: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6250 - auc: 0.8125 - loss: 0.7018 - precision: 0.6667 - sensitivity: 0.5000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step - accuracy: 0.8800 - auc: 0.9135 - loss: 0.4217 - precision: 0.8125 - sensitivity: 1.0000 - val_accuracy: 0.5714 - val_auc: 0.7500 - val_loss: 0.6797 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 26 Mulai
# ____________________________________________________________________________________________________
# Epoch 26/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7500 - auc: 0.9524 - loss: 0.4319 - precision: 0.8571 - sensitivity: 0.6667
# Epoch 26: val_loss improved from 0.67967 to 0.66739, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 26: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6250 - auc: 0.8125 - loss: 0.7164 - precision: 0.6667 - sensitivity: 0.5000
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step - accuracy: 0.7600 - auc: 0.9006 - loss: 0.6771 - precision: 0.8889 - sensitivity: 0.6154 - val_accuracy: 0.7143 - val_auc: 0.7500 - val_loss: 0.6674 - val_precision: 0.6667 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 27 Mulai
# ____________________________________________________________________________________________________
# Epoch 27/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7500 - auc: 0.8968 - loss: 0.6154 - precision: 0.8571 - sensitivity: 0.6667
# Epoch 27: val_loss improved from 0.66739 to 0.64485, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 27: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7500 - auc: 0.8125 - loss: 0.6987 - precision: 0.7500 - sensitivity: 0.7500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.8000 - auc: 0.9167 - loss: 0.6301 - precision: 0.9000 - sensitivity: 0.6923 - val_accuracy: 0.5714 - val_auc: 0.7500 - val_loss: 0.6448 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 28 Mulai
# ____________________________________________________________________________________________________
# Epoch 28/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8125 - auc: 0.7937 - loss: 1.2217 - precision: 0.8000 - sensitivity: 0.8889
# Epoch 28: val_loss improved from 0.64485 to 0.63094, saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Epoch 28: finished saving model to Model_B\dataset_1\MobileNet_v3.keras
#
# Model Terbaik → Evaluasi pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7500 - auc: 0.8125 - loss: 0.6880 - precision: 0.7500 - sensitivity: 0.7500
#
# Model Terbaik → Evaluasi pada VAL set
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step - accuracy: 0.8000 - auc: 0.8237 - loss: 1.0220 - precision: 0.7857 - sensitivity: 0.8462 - val_accuracy: 0.5714 - val_auc: 0.7500 - val_loss: 0.6309 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 29 Mulai
# ____________________________________________________________________________________________________
# Epoch 29/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8750 - auc: 0.9841 - loss: 0.2254 - precision: 1.0000 - sensitivity: 0.7778
# Epoch 29: val_loss did not improve from 0.63094
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8400 - auc: 0.9423 - loss: 0.6995 - precision: 1.0000 - sensitivity: 0.6923 - val_accuracy: 0.5714 - val_auc: 0.8333 - val_loss: 0.6573 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 30 Mulai
# ____________________________________________________________________________________________________
# Epoch 30/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8125 - auc: 0.9683 - loss: 0.3188 - precision: 0.8000 - sensitivity: 0.8889
# Epoch 30: val_loss did not improve from 0.63094
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8400 - auc: 0.9263 - loss: 0.6787 - precision: 0.8462 - sensitivity: 0.8462 - val_accuracy: 0.5714 - val_auc: 0.8333 - val_loss: 0.7306 - val_precision: 0.5000 - val_sensitivity: 0.6667
# ____________________________________________________________________________________________________
#
#  Epoch 31 Mulai
# ____________________________________________________________________________________________________
# Epoch 31/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9375 - auc: 1.0000 - loss: 0.1145 - precision: 0.9000 - sensitivity: 1.0000
# Epoch 31: val_loss did not improve from 0.63094
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8800 - auc: 0.9487 - loss: 0.2980 - precision: 0.9167 - sensitivity: 0.8462 - val_accuracy: 0.7143 - val_auc: 0.8333 - val_loss: 0.8458 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 32 Mulai
# ____________________________________________________________________________________________________
# Epoch 32/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8750 - auc: 0.9524 - loss: 0.4518 - precision: 0.8182 - sensitivity: 1.0000
# Epoch 32: val_loss did not improve from 0.63094
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8800 - auc: 0.9679 - loss: 0.3557 - precision: 0.8125 - sensitivity: 1.0000 - val_accuracy: 0.7143 - val_auc: 0.8333 - val_loss: 0.9400 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 33 Mulai
# ____________________________________________________________________________________________________
# Epoch 33/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9375 - auc: 0.9841 - loss: 0.1858 - precision: 0.9000 - sensitivity: 1.0000
# Epoch 33: val_loss did not improve from 0.63094
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9600 - auc: 0.9936 - loss: 0.1319 - precision: 0.9286 - sensitivity: 1.0000 - val_accuracy: 0.7143 - val_auc: 0.8333 - val_loss: 0.9658 - val_precision: 0.6000 - val_sensitivity: 1.0000
# ____________________________________________________________________________________________________
#
#  Epoch 34 Mulai
# ____________________________________________________________________________________________________
# Epoch 34/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9375 - auc: 0.9048 - loss: 0.6275 - precision: 0.9000 - sensitivity: 1.0000
# Epoch 34: val_loss did not improve from 0.63094
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8800 - auc: 0.9263 - loss: 0.4797 - precision: 0.8571 - sensitivity: 0.9231 - val_accuracy: 0.7143 - val_auc: 0.8333 - val_loss: 0.9477 - val_precision: 0.6000 - val_sensitivity: 1.0000
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 28.
# __________________________________________________
#
# Training selesai.
#
# Hasil Epoch Terbaik 28 → Evaluasi Hasil Akhir Terbaik pada TEST set
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7500 - auc: 0.8125 - loss: 0.6880 - precision: 0.7500 - sensitivity: 0.7500
# __________________________________________________
#
#  Waktu iterasi: 32 detik
# __________________________________________________
#
# ======================
#        RINGKASAN
# ======================
# Total iterasi            : 3
# Total waktu              : 2 menit 14 detik
# Rata-rata waktu/iterasi  : 44 detik

# %% [markdown]
# # 5. EVALUASI MODEL
# ___

# %% [markdown]
# ### Fungsi Metrics Utilites

# %%
# ============================================================
# Fungsi Menghitung Specificity Score
# TN / (TN + FP)
# ============================================================
def specificity_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    return tn / (tn + fp) if (tn + fp) > 0 else 0.0


# ============================================================
# Fungsi Menghitung Seluruh Metrik Klasifikasi Utam
# Accuracy, Recall, Specificity, Precision, F1-Score, dan AUC
# ============================================================
def compute_classification_metrics(y_true, y_pred, y_prob=None):
    metrics = {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred, zero_division=0),
        "Specificity": specificity_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred, zero_division=0),
        "F1-Score": f1_score(y_true, y_pred, zero_division=0),
    }

    if y_prob is not None:
        metrics["AUC"] = roc_auc_score(y_true, y_prob)

    return {
        "data": {
            "y_true": y_true.tolist(),
            "y_pred": y_pred.tolist(),
            "confusion_matrix": confusion_matrix(y_true, y_pred).tolist(),
            "class_names": np.unique(y_true).tolist(),
        },
        "metrics": metrics,
    }

# %% [markdown]
# ### Core Model Evaluation (ML/DL)

# %%
# ============================================================
# Fungsi Evaluasi performa model (ML atau DL), termasuk:
# - prediksi
# - metrik klasifikasi
# - waktu komputasi
# - penggunaan memori
# ============================================================
def evaluate_model_performance(model, X=None, y=None, test_dataset=None):
    start_time = time.perf_counter()
    tracemalloc.start()

    y_true, y_pred, y_prob = [], [], None

    # ===================== DEEP LEARNING =====================
    if test_dataset is not None:
        y_prob = []

        for images, labels in test_dataset:
            probs = model.predict(images, verbose=0).reshape(-1)
            preds = (probs >= 0.5).astype(int)

            y_true.extend(labels.numpy())
            y_pred.extend(preds)
            y_prob.extend(probs)

        y_true = np.array(y_true)
        y_pred = np.array(y_pred)
        y_prob = np.array(y_prob)

    # ===================== MACHINE LEARNING ==================
    else:
        y_true = np.asarray(y)
        y_pred = model.predict(X)

        if hasattr(model, "predict_proba"):
            y_prob = model.predict_proba(X)[:, 1]

    # ===================== RESOURCE USAGE ====================
    current_mem, peak_mem = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    elapsed_time = time.perf_counter() - start_time

    results = compute_classification_metrics(y_true, y_pred, y_prob)
    results["resources"] = {
        "computational_time_sec": elapsed_time,
        "memory_footprint_MB": current_mem / (1024 ** 2),
        "memory_peak_MB": peak_mem / (1024 ** 2),
    }

    return results

# %% [markdown]
# ### Stability Analysis (ML & DL)

# %%
# ============================================================
# Fungsi Menambahkan Gaussian noise ke image dataset (Deep Learning).
# ============================================================
def add_gaussian_noise_to_dataset(dataset, stddev):
    def _apply_noise(images, labels):
        noise = tf.random.normal(
            shape=tf.shape(images),
            mean=0.0,
            stddev=stddev,
            dtype=images.dtype
        )
        images_noisy = tf.clip_by_value(images + noise, 0.0, 1.0)
        return images_noisy, labels

    return dataset.map(_apply_noise, num_parallel_calls=tf.data.AUTOTUNE)


# ============================================================
# Fungsi Menghitung Stability Index model terhadap variasi Gaussian noise (ML/DL).
# ============================================================
def evaluate_stability_index(model, X=None, y=None, test_dataset=None,
                             noise_levels=(0.01, 0.03, 0.05), threshold=0.5, random_state=42,):
  
    rng = np.random.default_rng(random_state)
    scores = []

    for noise_std in noise_levels:

        # ===================== DEEP LEARNING =====================
        if test_dataset is not None:
            noisy_dataset = add_gaussian_noise_to_dataset(test_dataset, noise_std)
            y_true, y_pred = [], []

            for images, labels in noisy_dataset:
                probs = model.predict(images, verbose=0).reshape(-1)
                preds = (probs >= threshold).astype(int)
                y_true.extend(labels.numpy())
                y_pred.extend(preds)

            y_true = np.array(y_true)
            y_pred = np.array(y_pred)

        # ===================== MACHINE LEARNING ==================
        else:
            noise = rng.normal(0.0, noise_std, X.shape)
            X_noisy = X + noise
            y_true = np.asarray(y)
            y_pred = model.predict(X_noisy)

        score = accuracy_score(y_true, y_pred)
        scores.append(score)

    scores = np.array(scores)
    stability_index = 1.0 - (scores.std() / (scores.mean() + 1e-8))

    return {
        "noise_levels": list(noise_levels),
        "scores": scores.tolist(),
        "stability_index": float(stability_index),
        "metric_used": "Accuracy",
    }

# %% [markdown]
# ### Pipeline Evaluation (Multi-Model)

# %%
# ============================================================
# Pipeline evaluasi banyak model (ML atau DL).
# ============================================================
def run_evaluation_pipeline(model_names, model_dir, dataset_name,
                            X=None, y=None, test_dataset=None,
                            current_iter=0, total_iter=1, elapsed_dt=0.0, results_store=None):
    if results_store is None:
        results_store = {}

    is_dl = test_dataset is not None
    # Tipe model berdasarkan extension file
    model_type = "Deep Learning" if is_dl else "Machine Learning"
    model_ext = ".keras" if is_dl else ".pkl"

    print(f"\n--- Evaluasi {model_type} | Dataset: {dataset_name} ---")
    # 
    for model_name in model_names:
        current_iter += 1
        # Lokasi Model
        model_path = os.path.join(model_dir, f"{model_name}{model_ext}")
        # Lokasi History Model
        history_path = os.path.join(model_dir, f"history_{model_name}.pkl")

        if not os.path.exists(model_path):
            print(f"[{current_iter}/{total_iter}] {model_name} → SKIP")
            continue

        print(f"[{current_iter}/{total_iter}] {model_name} → Evaluating")

        # Load model
        model = (tf.keras.models.load_model(model_path) if is_dl else pickle.load(open(model_path, "rb")))

        # Core evaluation
        metrics = evaluate_model_performance(model, X=X, y=y, test_dataset=test_dataset)

        # Stability analysis
        metrics["stability"] = evaluate_stability_index(model, X=X, y=y, test_dataset=test_dataset)

        # Model size
        metrics["resources"]["model_size_MB"] = (os.path.getsize(model_path) / (1024 ** 2))

        # Training history (DL)
        if os.path.exists(history_path):
            with open(history_path, "rb") as f:
                metrics["history_train"] = pickle.load(f)
        else:
            metrics["history_train"] = None

        # example = {dataset_1_SVM: 
        results_store[f"{dataset_name}_{model_name}"] = metrics

        print(f"\tAccuracy : {metrics['metrics']['Accuracy']:.4f}")
        print(f"\tTime     : {metrics['resources']['computational_time_sec']:.4f} s")

    return current_iter, results_store

# %% [markdown]
# ## Proses Evaluasi Model

# %%
models_ml = ["SVM", "KNN", "RandomForest", "LogisticRegression", "MLP"]
models_dl = ["EfficientNet_B0", "ResNet50", "MobileNet_v3"]

results = {}
current_iter = 0

for dataset_name, split in dict_split.items():
    X_test = np.array(split["X_test"])
    y_test = np.array(split["y_test"])

    test_ds = convert_dataframe_to_tensor(
        df=df.iloc[split["X_test"].index.tolist()],
        base_path=PATH_FOLDER["dataset_extract_b"],
        image_size=IMAGE_SIZE,
    )

    model_path = os.path.join(PATH_FOLDER["path_model_b"], dataset_name)

    # ============== Machine Learning ==============
    current_iter, results = run_evaluation_pipeline(
        model_names=models_ml,
        model_dir=model_path,
        dataset_name=dataset_name,
        X=X_test,
        y=y_test,
        current_iter=current_iter,
        total_iter=len(models_ml) + len(models_dl),
        results_store=results,
    )

    # ============== Deep Learning ==============
    current_iter, results = run_evaluation_pipeline(
        model_names=models_dl,
        model_dir=model_path,
        dataset_name=dataset_name,
        test_dataset=test_ds,
        current_iter=current_iter,
        total_iter=len(models_ml) + len(models_dl),
        results_store=results,
    )
# Out:
# --- Evaluasi Machine Learning | Dataset: dataset_1 ---
# [1/8] SVM → Evaluating
# 	Accuracy : 0.6250
# 	Time     : 0.0038 s
# [2/8] KNN → Evaluating
# 	Accuracy : 0.5000
# 	Time     : 0.0365 s
# [3/8] RandomForest → Evaluating
# 	Accuracy : 0.7500
# 	Time     : 0.0687 s
# [4/8] LogisticRegression → Evaluating
# 	Accuracy : 0.7500
# 	Time     : 0.0030 s
# [5/8] MLP → Evaluating
# 	Accuracy : 0.5000
# 	Time     : 0.0024 s
#
# --- Evaluasi Deep Learning | Dataset: dataset_1 ---
# [6/8] EfficientNet_B0 → Evaluating
# 	Accuracy : 0.7500
# 	Time     : 6.4554 s
# [7/8] ResNet50 → Evaluating
# 	Accuracy : 0.7500
# 	Time     : 5.9493 s
# [8/8] MobileNet_v3 → Evaluating
# 	Accuracy : 0.7500
# 	Time     : 3.6875 s

# %%
# Simpan hasil akhir ke json
with open('skenario_B_final.json', "w") as f:
    json.dump(results, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Visualisasi

# %%
with open('skenario_B_final.json', 'r') as f:
    results = json.load(f)

# %%
# %matplotlib inline
# ============================================================
# Fungsi Visualisasi Evaluasi Model
# ============================================================
def visualisasi(dict_results, list_sumber, display):
    for sumber in list_sumber:

        # Struktur penampung data
        history_cnn  = {'history_list': [], 'titles': []}
        conf_matrix  = {'conf_matrices': [], 'titles': [], 'class_names': None}
        eval_metrics = {'metrics_list': [], 'titles': []}
        comput_time = {'results': [], 'titles': []}
        rss_usage = {'results': [], 'titles': []}
        stability_result = {'results':[], 'titles':[]}

        # Filter semua model berdasarkan sumber
        model_keys = [k for k in dict_results if k.startswith(sumber)]

        for key in model_keys:
            result = dict_results[key]
            model_name = key.split(f"{sumber}_", 1)[1]

            # -------------------------------------------------------
            # HISTORY TRAINING CNN
            # -------------------------------------------------------
            history_dict = result.get("history_train")
            if history_dict:
                history_cnn['history_list'].append(dict(history_dict))
                history_cnn['titles'].append(f"History Training {model_name} - {sumber}")

            # -------------------------------------------------------
            # CONFUSION MATRIX
            # -------------------------------------------------------
            data_block = result.get("data")
            if data_block:
                cm          = data_block.get("confusion_matrix")
                class_names = data_block.get("class_names")

                if cm is not None:
                    conf_matrix['conf_matrices'].append(cm)
                    conf_matrix['titles'].append(model_name)
                    conf_matrix['class_names'] = class_names

            # -------------------------------------------------------
            # EVALUASI METRIK MODEL
            # -------------------------------------------------------
            metrics = result.get("metrics")
            if metrics:
                eval_metrics['metrics_list'].append(dict(metrics))
                eval_metrics['titles'].append(model_name)

            resources = result.get("resources")
            if resources:
                # -------------------------------------------------------
                # Computational Time
                # -------------------------------------------------------
                comput_time['results'].append(resources)
                comput_time['titles'].append(model_name)
                # -------------------------------------------------------
                # Resource Usage Comparison
                # -------------------------------------------------------
                rss_usage['results'].append(resources)
                rss_usage['titles'].append(model_name)
            # -------------------------------------------------------
            # Stability Index
            # -------------------------------------------------------
            stability = result.get("stability")
            if stability:
                stability_result['results'].append(stability) 
                stability_result['titles'].append(model_name)


        # =======================================================
        # TAMPILKAN SEMUA VISUALISASI SESUAI REQUEST
        # =======================================================
        if "history_cnn" in display:
            myplot.plot_history_cnn_grid(**history_cnn, save_as=os.path.join(PATH_FOLDER['path_plot'], "history_cnn_B.png"))

        if "confusion_matrix" in display:
            myplot.plot_confusion_matrices_grid(
                **conf_matrix,
                main_title=f"Confusion Matrix | {sumber}",
                max_cols=max(1, len(conf_matrix['conf_matrices']) // 2),
                save_as=os.path.join(PATH_FOLDER['path_plot'], "confusion_matrix_B.png")
            )

        if "evaluate_models" in display:
            myplot.plot_classification_metrics_bar(
                **eval_metrics,
                main_title=f"Model Evaluation Metrics | {sumber}",
                save_as=os.path.join(PATH_FOLDER['path_plot'], "evaluate_models_B.png")
            )
            
        if "computational_time" in display:
            myplot.plot_computational_time(
                **comput_time,
                main_title=f"Computational Time | {sumber}",
                save_as=os.path.join(PATH_FOLDER['path_plot'], "computational_time_B.png")
            )

        if 'resource_usage' in display:
            myplot.plot_resource_usage(
                **rss_usage,
                main_title=f"Resource Usage Comparison | {sumber}",
                save_as=os.path.join(PATH_FOLDER['path_plot'], "resource_usage_B.png")
            )
            
        if 'stability_index' in display:
            myplot.plot_stability_index(
                **stability_result,
                main_title=f"Stability Index Comparison | {sumber}",
                save_as=os.path.join(PATH_FOLDER['path_plot'], "stability_index_B.png")
            )

# %% [markdown]
# ### Visualisasi History Training CNN

# %%
visualisasi(dict_results=results, list_sumber=list(dict_split.keys()), display=['history_cnn'])

# %% [markdown]
# ### Visualisasi Confusion Matrix

# %%
visualisasi(dict_results=results, list_sumber=list(dict_split.keys()), display=['confusion_matrix'])

# %% [markdown]
# ### Visualisasi Evaluasi Model

# %%
visualisasi(dict_results=results, list_sumber=list(dict_split.keys()), display=['evaluate_models'])

# %% [markdown]
# ### Visualisasi Computational Time

# %%
visualisasi(dict_results=results, list_sumber=list(dict_split.keys()), display=['computational_time'])

# %% [markdown]
# ### Visualisasi Resource Usage

# %%
visualisasi(dict_results=results, list_sumber=list(dict_split.keys()), display=['resource_usage'])

# %% [markdown]
# ### Visualisasi Stability Index

# %%
visualisasi(dict_results=results, list_sumber=list(dict_split.keys()), display=['stability_index'])
